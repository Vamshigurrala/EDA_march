# %% [markdown]
# **Data transformation**
# - Generally data has 3 types of distributions
#     - Normal distribution
#     - pos skewed
#     - Neg skewed
# - all the math concepts developed by assumption as data follows normal distribution
# - Data skew happens because of many reasons, in that one reason is outliers
# - once we perform outlier analysis then we can apply transformation techinques
#   if the data does not follows normality
# - we have some transformation methods mentioned below
#     - Log transformation
#     - exponential tranformation
#     - reciprocal transformation
#     - square root transformation
#     - power transformation

# %% [markdown]
# **step-1:import packages**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **step-2:Read the data**

# %%
exp_data=np.random.exponential(size=10000)
exp_data
# Out:
# array([5.03699248, 2.04481137, 0.63830277, ..., 1.54675311, 0.21163074,
#        0.56836037])

# %% [markdown]
# **step-3:plot the data**

# %%
plt.hist(exp_data,bins=20,label='Exponential')
plt.show()

# %%
norm_data=np.random.normal(size=10000)
norm_data
# Out:
# array([ 0.15336391, -1.01577921, -1.66263537, ...,  0.02563075,
#        -1.95688327, -1.0046124 ])

# %%
plt.hist(norm_data,bins=20,label='Exponential')
plt.show()

# %% [markdown]
# **our task is to convert exp_data to Normal distibution**

# %% [markdown]
# **step-4:Log transformation**
# - Log transformation means performing logarithm operations on original data
# - it is an approach to convert into normal distibution
# - Log means natural logarithm base=e

# %%
x=2
np.log(x)
# Out:
# 0.6931471805599453

# %%
exp_data=np.random.exponential(size=10000)
log_data=np.log(exp_data)

# %%
plt.hist(log_data,bins=20,label='Logarithm')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1).hist(exp_data,bins=20,label='Exponential')
plt.legend()
plt.subplot(1,2,2).hist(log_data,bins=20,label='Logarithm')
plt.legend()
plt.show()

# %% [markdown]
# **Reciprocal Transformation**

# %%
x=2
1/x
# Out:
# 0.5

# %%
exp_data=np.random.exponential(size=10000)
recip_data=1/exp_data
recip_data
# Out:
# array([0.51805547, 2.55980578, 0.68687694, ..., 1.41895956, 1.03889053,
#        0.6519319 ])

# %%
plt.hist(recip_data,bins=20,label='reciprocal')
plt.legend()
plt.show()

# %% [markdown]
# **Square root transformation**

# %%
sqr_data=np.sqrt(exp_data)
plt.hist(sqr_data,bins=20,label='Square root data')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,4,1).hist(exp_data,bins=20,label='Exponential')
plt.legend()
plt.subplot(1,4,2).hist(log_data,bins=20,label='Logarithm')
plt.legend()
plt.subplot(1,4,3).hist(sqr_data,bins=20,label='square root')
plt.legend()
plt.subplot(1,4,4).hist(recip_data,bins=20,label='reciprocal')
plt.legend()
plt.show()

# %% [markdown]
# **Power transformation**
# - Box cox
# - ye-jhonson
# - it is under sklearn preprocessing

# %%
import numpy as np
from sklearn.preprocessing import PowerTransformer

power=PowerTransformer(method='yeo-johnson')
data1=power.fit_transform(exp_data.reshape(-1,1))

powr_box=PowerTransformer(method='box-cox')
data2=powr_box.fit_transform(exp_data.reshape(-1,1))

plt.figure(figsize=(14,5))
plt.subplot(1,2,1).hist(data1,bins=20,label='yeo-johnson')
plt.legend()
plt.subplot(1,2,2).hist(data2,bins=20,label='Box_cox')
plt.legend()
plt.show()
