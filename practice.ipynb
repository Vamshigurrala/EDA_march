# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
names=['vamshi','ramraj','Krishna']
Age=[25,35,45]
city=['wgl','Hyd','Blr']

# %%
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pd.DataFrame(zip(names,Age,city),
             columns=['Names','Age','city'])
# Out:
#      Names  Age city
# 0   vamshi   25  wgl
# 1   ramraj   35  Hyd
# 2  Krishna   45  Blr

# %%
data=zip(names,Age,city)
cols=['Names','Age','City']
df=pd.DataFrame(data,columns=cols)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
salary=[25000,35000,45000]
df['salary']=salary

# %%
df
# Out:
#      Names  Age City  salary
# 0   vamshi   25  wgl   25000
# 1   ramraj   35  Hyd   35000
# 2  Krishna   45  Blr   45000

# %%
df['Age']=[35,40,45]

# %%
df
# Out:
#      Names  Age City  salary
# 0   vamshi   35  wgl   25000
# 1   ramraj   40  Hyd   35000
# 2  Krishna   45  Blr   45000

# %%
data=zip(names,Age,city)
cols=['Names','Age','City']
df=pd.DataFrame(data,index=['A','B','C'],columns=cols)

# %%
df['job']=['DE','DS','CS']
df
# Out:
#      Names  Age City job
# A   vamshi   25  wgl  DE
# B   ramraj   35  Hyd  DS
# C  Krishna   45  Blr  CS

# %%
a=df.shape[0]
b=df.shape[1]
print(f'the number of rows are {a}')
print(f'the number of columns are {b}')
# Out:
# the number of rows are 3
# the number of columns are 4

# %%
df.drop('job',axis=1,inplace=True)

# %%
df
# Out:
#      Names  Age City
# A   vamshi   25  wgl
# B   ramraj   35  Hyd
# C  Krishna   45  Blr

# %%
new=df.drop('City',axis=1)

# %%
new
# Out:
#      Names  Age
# A   vamshi   25
# B   ramraj   35
# C  Krishna   45

# %%
df
# Out:
#      Names  Age City
# A   vamshi   25  wgl
# B   ramraj   35  Hyd
# C  Krishna   45  Blr

# %%
df.drop('C',axis=0)
# Out:
#     Names  Age City
# A  vamshi   25  wgl
# B  ramraj   35  Hyd

# %%
df
# Out:
#      Names  Age City
# A   vamshi   25  wgl
# B   ramraj   35  Hyd
# C  Krishna   45  Blr

# %%
df.drop(['Age','City'],axis=1,inplace=True)

# %%
data=zip(names,Age,city)
cols=['Names','Age','City']
df=pd.DataFrame(data,index=['A','B','C'],columns=cols)
df
# Out:
#      Names  Age City
# A   vamshi   25  wgl
# B   ramraj   35  Hyd
# C  Krishna   45  Blr

# %%
df.to_csv('Data.csv',index=False)

# %% [markdown]
# **How to read a dataframe**

# %%
pd.read_csv('data1.csv')
# Out:
#       Name  Age     city
# 0  Avinash   30      Blr
# 1    Akash   35   Mumbai
# 2     Anvi   40  chennai

# %%
df=pd.read_excel('data2.xlsx')

# %%
df
# Out:
#   Unnamed: 0     Name  Age     city
# 0          B  Avinash   30      Blr
# 1          C    Akash   35   Mumbai
# 2          D     Anvi   40  chennai

# %%
df.drop('Unnamed: 0',axis=1)
# Out:
#       Name  Age     city
# 0  Avinash   30      Blr
# 1    Akash   35   Mumbai
# 2     Anvi   40  chennai

# %%
pd.read_csv("Visadataset - Visadataset.csv")
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
pd.read_csv(r"C:\Users\vamsh\OneDrive\NARESHIT\DATA_FOLDER\bank - bank.csv")
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
Names=['vamshi','Ramu','Krishna']
Age=[25,35,40]
pd.DataFrame(zip(Names,Age),columns=['Names','Age'])
# Out:
#      Names  Age
# 0   vamshi   25
# 1     Ramu   35
# 2  Krishna   40

# %%
dict={'Names':['vamshi','Ramu','Krishna'],
      'Age':[25,35,40]}

# %%
dict
# Out:
# {'Names': ['vamshi', 'Ramu', 'Krishna'], 'Age': [25, 35, 40]}

# %%
pd.DataFrame(dict)
# Out:
#      Names  Age
# 0   vamshi   25
# 1     Ramu   35
# 2  Krishna   40

# %%
dict2={'Name':'vamshi',
        'Age':25,
        'city':'blr'}
dict2
# Out:
# {'Name': 'vamshi', 'Age': 25, 'city': 'blr'}

# %%
pd.DataFrame(dict2,index=['A',2,3])
# Out:
#      Name  Age city
# A  vamshi   25  blr
# 2  vamshi   25  blr
# 3  vamshi   25  blr

# %%
visa_df=pd.read_csv("Visadataset - Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df.tail()
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 25470  EZYV25471  North America              Master's                  Y
# 25471  EZYV25472           Asia           High School                  N
# 25472  EZYV25473           Asia           High School                  N
# 25473  EZYV25474           Asia            Bachelor's                  Y
# 25474  EZYV25475         Africa             Doctorate                  N
# 25475  EZYV25476           Asia            Bachelor's                  Y
# 25476  EZYV25477           Asia           High School                  Y
# 25477  EZYV25478           Asia              Master's                  Y
# 25478  EZYV25479           Asia              Master's                  Y
# 25479  EZYV25480           Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25470                     N             2272         1970
# ...

# %%
visa_df.shape
# Out:
# (25480, 12)

# %%
print(f'the number of rows are: {visa_df.shape[0]}')
print(f'the number of columns are: {visa_df.shape[1]}')
# Out:
# the number of rows are: 25480
# the number of columns are: 12

# %%
visa_df.size
# Out:
# 305760

# %%
25480*12
# Out:
# 305760
